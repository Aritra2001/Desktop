# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
dataset=pd.read_csv('weather.csv')
print(dataset.shape)
# Out:
# (366, 22)

# %%
print(dataset.describe)
# Out:
# <bound method NDFrame.describe of      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
print(dataset.head)
# Out:
# <bound method NDFrame.head of      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
dataset.plot(x='MinTemp', y='MaxTemp' , style='o')
plt.title('min vs max')
plt.xlabel('mintemp')
plt.ylabel('maxtemp')
plt.show()

# %%
dataset.plot(x='Humidity3pm', y='MaxTemp' , style='o')
plt.title('humidity vs temp')
plt.xlabel('Humidity3pm')
plt.ylabel('maxtemp')
plt.show()

# %%
dataset.plot(x='Sunshine', y='MaxTemp' , style='o')
plt.title('Sunshine vs temp')
plt.xlabel('Humidity3pm')
plt.ylabel('maxtemp')
plt.show()

# %%
dataset.plot(x='Sunshine', y='MinTemp' , style='o')
plt.title('Sunshine vs temp')
plt.xlabel('Humidity3pm')
plt.ylabel('mintemp')
plt.show()

# %%
dataset.plot(x='Rainfall', y='MaxTemp' , style='o')
plt.title('Rainfall vs temp')
plt.xlabel('Rainfall')
plt.ylabel('maxtemp')
plt.show()

# %%
dataset.plot(x='Cloud3pm', y='Rainfall' , style='o')
plt.title('Rainfall vs cloud')
plt.xlabel('Cloud3pm')
plt.ylabel('Rainfall')
plt.show()

# %%
dataset.plot(x='MaxTemp', y='Rainfall' , style='o')
plt.title('Rainfall vs temperature')
plt.xlabel('MaxTemp')
plt.ylabel('Rainfall')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seaborn.histplot(dataset['MaxTemp'])
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seaborn.histplot(dataset['MinTemp'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 plt.figure(figsize=(15,10))
#       2 plt.tight_layout()
#       3 seaborn.histplot(dataset['MinTemp'])
#
# NameError: name 'plt' is not defined
